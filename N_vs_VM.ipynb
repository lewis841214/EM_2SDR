# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

it_list = []
vm_list = []
exp_name = f'20220211_3DVA_data_mean_by_EM_PCA_after_subtract_senior_mean_EM_2SDR_n_18'
dir_path = f'/home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/TSNE_result/{exp_name}'
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(dir_path) if isfile(join(dir_path, f))]

for file in onlyfiles:

    if len(file.split('-')) == 2:
        #print(file.split('-')[1].split())
        it = float(file.split('-')[1].split()[0])
        vm = float(file.split('-')[1].split()[3].split('j')[0][:-1])
        #print(it, vm)
        it_list.append(it)
        vm_list.append(vm)
    it_list = np.array(it_list)
    vm_list = np.array(vm_list)
    sort = np.argsort(it_list)
    it_list = it_list[sort].tolist()
    vm_list = vm_list[sort].tolist()

plt.plot(it_list, vm_list, label = '-avg -EMPCA mean')
plt.legend()
plt.title(f' 2SDR')
plt.xlabel('iter')
plt.ylabel('v_measure')
it_list = []
vm_list = []
exp_name = f'20220211_3DVA_data_EM_2SDR_n_19_senior_mean'
dir_path = f'/home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/TSNE_result/{exp_name}'
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(dir_path) if isfile(join(dir_path, f))]

for file in onlyfiles:

    if len(file.split('-')) == 2:
        #print(file.split('-')[1].split())
        it = float(file.split('-')[1].split()[0])
        vm = float(file.split('-')[1].split()[3].split('j')[0][:-1])
        #print(it, vm)
        it_list.append(it)
        vm_list.append(vm)
    it_list = np.array(it_list)
    vm_list = np.array(vm_list)
    sort = np.argsort(it_list)
    it_list = it_list[sort].tolist()
    vm_list = vm_list[sort].tolist()

plt.plot(it_list, vm_list, label = '-avg')
plt.legend()
plt.title(f' 2SDR')
plt.xlabel('iter')
plt.ylabel('v_measure')
plt.show()

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

it_list = []
vm_list = []
exp_name = f'20220212_3DVA_data_mean_by_EM_PCA_after_subtract_senior_mean_EM_2SDR_n_20_18_is_pretrained'
dir_path = f'/home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/TSNE_result/{exp_name}'
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(dir_path) if isfile(join(dir_path, f))]

for file in onlyfiles:

    if len(file.split('-')) == 2:
        #print(file.split('-')[1].split())
        it = float(file.split('-')[1].split()[0])
        vm = float(file.split('-')[1].split()[3].split('j')[0][:-1])
        #print(it, vm)
        it_list.append(it)
        vm_list.append(vm)
    it_list = np.array(it_list)
    vm_list = np.array(vm_list)
    sort = np.argsort(it_list)
    it_list = it_list[sort].tolist()
    vm_list = vm_list[sort].tolist()

plt.plot(it_list, vm_list)
plt.legend()
plt.title(f'2SDR')
plt.xlabel('iter')
plt.ylabel('v_measure')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

it_list = []
vm_list = []
exp_name = f'20220211_3DVA_data_EM_2SDR_n_19_senior_mean'
dir_path = f'/home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/TSNE_result/{exp_name}'
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(dir_path) if isfile(join(dir_path, f))]

for file in onlyfiles:

    if len(file.split('-')) == 2:
        #print(file.split('-')[1].split())
        it = float(file.split('-')[1].split()[0])
        vm = float(file.split('-')[1].split()[3].split('j')[0][:-1])
        #print(it, vm)
        it_list.append(it)
        vm_list.append(vm)
    it_list = np.array(it_list)
    vm_list = np.array(vm_list)
    sort = np.argsort(it_list)
    it_list = it_list[sort].tolist()
    vm_list = vm_list[sort].tolist()

plt.plot(it_list, vm_list)
plt.legend()
plt.title(f' 2SDR')
plt.xlabel('iter')
plt.ylabel('v_measure')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
n = 24
n_list = [2,5,7, 10, 15, 22, 24]
n_list.reverse()
for n in n_list:
    it_list = []
    vm_list = []
    exp_name = f'20220211_3DVA_data_EM_2SDR_n_19_senior_mean'
    dir_path = f'/home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo/TSNE_result/{exp_name}'
    from os import listdir
    from os.path import isfile, join
    onlyfiles = [f for f in listdir(dir_path) if isfile(join(dir_path, f))]

    for file in onlyfiles:

        if len(file.split('-')) == 2:
            #print(file.split('-')[1].split())
            it = float(file.split('-')[1].split()[0])
            vm = float(file.split('-')[1].split()[3].split('j')[0][:-1])
            #print(it, vm)
            it_list.append(it)
            vm_list.append(vm)
        it_list = np.array(it_list)
        vm_list = np.array(vm_list)
        sort = np.argsort(it_list)
        it_list = it_list[sort].tolist()
        vm_list = vm_list[sort].tolist()
    
    plt.plot(it_list, vm_list, label = f'n = {n}')
plt.legend()
plt.title(f'noised 2SDR')
plt.xlabel('iter')
plt.ylabel('v_measure')
plt.show()

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
n = 24
snr_list = [10, 5, 1, 0.8, 0.6, 0.4, 0.2, 0.1]
plt.figure(figsize = (20, 10))
for snr in snr_list:
    it_list = []
    vm_list = []
    exp_name = f'20220308_70s_2class_0304+{snr}_EM_2SDR_n_8'
    dir_path = f'/home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/TSNE_result/{exp_name}'
    from os import listdir
    from os.path import isfile, join
    onlyfiles = [f for f in listdir(dir_path) if isfile(join(dir_path, f))]
    print('snr=' , snr)
    for file in onlyfiles:
        #print('file.split()', file.split('-'))
        ss = file[:-9].split('-')
        #print(ss)
        #if len(file.split('-')) == 2:
        if len(ss) == 2:
            #print(file.split('-')[1].split())
            it = float(ss[1].split()[0])
            vm = float(ss[1].split()[3].split('j')[0][:-1])
            print(it, vm)
            it_list.append(it)
            vm_list.append(vm)
        
        it_list = np.array(it_list)
        vm_list = np.array(vm_list)
        sort = np.argsort(it_list)
        it_list = it_list[sort].tolist()
        vm_list = vm_list[sort].tolist()
    
    plt.plot(it_list, vm_list, label = f'snr = {snr}')
plt.legend()
plt.title(f'noised 2SDR')
plt.xlabel('iter')
plt.ylabel('v_measure')
plt.show()
# Out:
# snr= 10
# 17.0 1.0
# 11.0 1.0
# 14.0 1.0
# 20.0 1.0
# 1.0 1.0
# 4.0 1.0
# 7.0 1.0
# 10.0 1.0
# snr= 5
# 11.0 1.0
# 10.0 1.0
# 1.0 1.0
# 14.0 1.0
# 20.0 0.785
# 17.0 0.936
# 4.0 1.0
# 7.0 1.0
# snr= 1
# 7.0 0.943
# 17.0 0.296
# 10.0 0.859
# 20.0 0.166
# 4.0 1.0
# 14.0 0.54
# 11.0 0.794
# 1.0 1.0
# snr= 0.8
# 4.0 0.977
# 17.0 0.3
# 10.0 0.794
# 1.0 0.977
# 11.0 0.764
# 14.0 0.524
# 7.0 0.929
# 20.0 0.118
# snr= 0.6
# 17.0 0.209
# 10.0 0.721
# 7.0 0.929
# 4.0 0.943
# 1.0 0.959
# 14.0 0.372
# 11.0 0.613
# 20.0 0.087
# snr= 0.4
# 7.0 0.697
# 17.0 0.163
# 1.0 0.832
# 4.0 0.775
# 20.0 0.103
# 14.0 0.313
# 10.0 0.573
# 11.0 0.531
# snr= 0.2
# 11.0 0.348
# 7.0 0.555
# 14.0 0.17
# 1.0 0.769
# 10.0 0.383
# 17.0 0.081
# 4.0 0.643
# 20.0 0.041
# snr= 0.1
# 1.0 0.39
# 20.0 0.036
# 4.0 0.346
# 7.0 0.271
# 17.0 0.071
# 10.0 0.23
# 14.0 0.145
# 11.0 0.216

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
n = 24
n_list = [2,7, 10, 15,18, 22]
for n in n_list:
    it_list = []
    vm_list = []
    exp_name = f'20220107_n_{n}_MPCA_tsne_iter'
    dir_path = f'/home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo/TSNE_result/{exp_name}'
    from os import listdir
    from os.path import isfile, join
    onlyfiles = [f for f in listdir(dir_path) if isfile(join(dir_path, f))]

    for file in onlyfiles:

        if len(file.split('-')) == 2:
            #print(file.split('-')[1].split())
            it = float(file.split('-')[1].split()[0])
            vm = float(file.split('-')[1].split()[3].split('j')[0][:-1])
            #print(it, vm)
            it_list.append(it)
            vm_list.append(vm)
        it_list = np.array(it_list)
        vm_list = np.array(vm_list)
        sort = np.argsort(it_list)
        it_list = it_list[sort].tolist()
        vm_list = vm_list[sort].tolist()
    
    plt.plot(it_list, vm_list, label = f'n={n}')
plt.title(f'clean 2SDR')
plt.xlabel('iter')
plt.ylabel('v_measure')
plt.legend()
plt.show()
