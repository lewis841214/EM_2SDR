# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

it_list = []
vm_list = []
exp_name = f'20220211_3DVA_data_mean_by_EM_PCA_after_subtract_senior_mean_EM_2SDR_n_18'
dir_path = f'/home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/TSNE_result/{exp_name}'
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(dir_path) if isfile(join(dir_path, f))]

for file in onlyfiles:

    if len(file.split('-')) == 2:
        #print(file.split('-')[1].split())
        it = float(file.split('-')[1].split()[0])
        vm = float(file.split('-')[1].split()[3].split('j')[0][:-1])
        #print(it, vm)
        it_list.append(it)
        vm_list.append(vm)
    it_list = np.array(it_list)
    vm_list = np.array(vm_list)
    sort = np.argsort(it_list)
    it_list = it_list[sort].tolist()
    vm_list = vm_list[sort].tolist()

plt.plot(it_list, vm_list, label = '-avg -EMPCA mean')
plt.legend()
plt.title(f' 2SDR')
plt.xlabel('iter')
plt.ylabel('v_measure')
it_list = []
vm_list = []
exp_name = f'20220211_3DVA_data_EM_2SDR_n_19_senior_mean'
dir_path = f'/home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/TSNE_result/{exp_name}'
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(dir_path) if isfile(join(dir_path, f))]

for file in onlyfiles:

    if len(file.split('-')) == 2:
        #print(file.split('-')[1].split())
        it = float(file.split('-')[1].split()[0])
        vm = float(file.split('-')[1].split()[3].split('j')[0][:-1])
        #print(it, vm)
        it_list.append(it)
        vm_list.append(vm)
    it_list = np.array(it_list)
    vm_list = np.array(vm_list)
    sort = np.argsort(it_list)
    it_list = it_list[sort].tolist()
    vm_list = vm_list[sort].tolist()

plt.plot(it_list, vm_list, label = '-avg')
plt.legend()
plt.title(f' 2SDR')
plt.xlabel('iter')
plt.ylabel('v_measure')
plt.show()

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

it_list = []
vm_list = []
exp_name = f'20220212_3DVA_data_mean_by_EM_PCA_after_subtract_senior_mean_EM_2SDR_n_20_18_is_pretrained'
dir_path = f'/home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/TSNE_result/{exp_name}'
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(dir_path) if isfile(join(dir_path, f))]

for file in onlyfiles:

    if len(file.split('-')) == 2:
        #print(file.split('-')[1].split())
        it = float(file.split('-')[1].split()[0])
        vm = float(file.split('-')[1].split()[3].split('j')[0][:-1])
        #print(it, vm)
        it_list.append(it)
        vm_list.append(vm)
    it_list = np.array(it_list)
    vm_list = np.array(vm_list)
    sort = np.argsort(it_list)
    it_list = it_list[sort].tolist()
    vm_list = vm_list[sort].tolist()

plt.plot(it_list, vm_list)
plt.legend()
plt.title(f'2SDR')
plt.xlabel('iter')
plt.ylabel('v_measure')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

it_list = []
vm_list = []
exp_name = f'20220211_3DVA_data_EM_2SDR_n_19_senior_mean'
dir_path = f'/home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/TSNE_result/{exp_name}'
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(dir_path) if isfile(join(dir_path, f))]

for file in onlyfiles:

    if len(file.split('-')) == 2:
        #print(file.split('-')[1].split())
        it = float(file.split('-')[1].split()[0])
        vm = float(file.split('-')[1].split()[3].split('j')[0][:-1])
        #print(it, vm)
        it_list.append(it)
        vm_list.append(vm)
    it_list = np.array(it_list)
    vm_list = np.array(vm_list)
    sort = np.argsort(it_list)
    it_list = it_list[sort].tolist()
    vm_list = vm_list[sort].tolist()

plt.plot(it_list, vm_list)
plt.legend()
plt.title(f' 2SDR')
plt.xlabel('iter')
plt.ylabel('v_measure')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
n = 24
n_list = [2,5,7, 10, 15, 22, 24]
n_list.reverse()
for n in n_list:
    it_list = []
    vm_list = []
    exp_name = f'20220211_3DVA_data_EM_2SDR_n_19_senior_mean'
    dir_path = f'/home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo/TSNE_result/{exp_name}'
    from os import listdir
    from os.path import isfile, join
    onlyfiles = [f for f in listdir(dir_path) if isfile(join(dir_path, f))]

    for file in onlyfiles:

        if len(file.split('-')) == 2:
            #print(file.split('-')[1].split())
            it = float(file.split('-')[1].split()[0])
            vm = float(file.split('-')[1].split()[3].split('j')[0][:-1])
            #print(it, vm)
            it_list.append(it)
            vm_list.append(vm)
        it_list = np.array(it_list)
        vm_list = np.array(vm_list)
        sort = np.argsort(it_list)
        it_list = it_list[sort].tolist()
        vm_list = vm_list[sort].tolist()
    
    plt.plot(it_list, vm_list, label = f'n = {n}')
plt.legend()
plt.title(f'noised 2SDR')
plt.xlabel('iter')
plt.ylabel('v_measure')
plt.show()

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
n = 24
snr_list = [10, 5, 1, 0.8, 0.6, 0.4, 0.2, 0.1]
for snr in snr_list:
    it_list = []
    vm_list = []
    exp_name = f'20220308_70s_2class_0304+{snr}_EM_2SDR_n_8'
    dir_path = f'/home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/TSNE_result/{exp_name}'
    from os import listdir
    from os.path import isfile, join
    onlyfiles = [f for f in listdir(dir_path) if isfile(join(dir_path, f))]
    print('snr=' , snr)
    for file in onlyfiles:
        #print('file.split()', file.split('-'))
        ss = file.split('-')[:-16]
        #if len(file.split('-')) == 2:
        if len(ss) == 2:
            #print(file.split('-')[1].split())
            it = float(ss[1].split()[0])
            vm = float(ss[1].split()[3].split('j')[0][:-1])
            print(it, vm)
            it_list.append(it)
            vm_list.append(vm)
        
        it_list = np.array(it_list)
        vm_list = np.array(vm_list)
        sort = np.argsort(it_list)
        it_list = it_list[sort].tolist()
        vm_list = vm_list[sort].tolist()
    
    plt.plot(it_list, vm_list, label = f'snr = {snr}')
plt.legend()
plt.title(f'noised 2SDR')
plt.xlabel('iter')
plt.ylabel('v_measure')
plt.show()
# Out:
# snr= 10
# file.split() ['n = 8 5Ribsome data true_index at iter', '17 vm = 1.0 log_proj_var =4.94.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '10 vm = 1.0 log_proj_var =5.25.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '10 vm = 1.0 log_proj_var =4.97.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '11 vm = 1.0 log_proj_var =5.32.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '20 vm = 1.0 log_proj_var =4.97.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '1 vm = 1.0 log_proj_var =5.13.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '14 vm = 1.0 log_proj_var =5.15.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '17 vm = 1.0 log_proj_var =4.94.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '10 vm = 1.0 log_proj_var =4.97.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '14 vm = 1.0 log_proj_var =5.15.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '20 vm = 1.0 log_proj_var =4.97.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '7 vm = 1.0 log_proj_var =5.56.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '1 vm = 1.0 log_proj_var =5.13.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '4 vm = 1.0 log_proj_var =5.87.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '4 vm = 1.0 log_proj_var =5.87.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '7 vm = 1.0 log_proj_var =5.56.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '11 vm = 1.0 log_proj_var =5.32.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '10 vm = 1.0 log_proj_var =5.25.jpg']
# snr= 5
# file.split() ['n = 8 5Ribsome data true_index at iter', '11 vm = 1.0 log_proj_var =2.52.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '10 vm = 0.7857 log_proj_var =', '2.37.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '11 vm = 1.0 log_proj_var =2.52.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '10 vm = 1.0 log_proj_var =2.94.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '1 vm = 1.0 log_proj_var =4.94.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '14 vm = 1.0 log_proj_var =1.05.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '10 vm = 1.0 log_proj_var =2.94.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '10 vm = 0.7857 log_proj_var =', '2.37.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '1 vm = 1.0 log_proj_var =4.94.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '17 vm = 0.9368 log_proj_var =', '0.60.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '7 vm = 1.0 log_proj_var =3.94.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '14 vm = 1.0 log_proj_var =1.05.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '20 vm = 0.7857 log_proj_var =', '2.37.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '4 vm = 1.0 log_proj_var =4.60.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '20 vm = 0.7857 log_proj_var =', '2.37.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '17 vm = 0.9368 log_proj_var =', '0.60.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '4 vm = 1.0 log_proj_var =4.60.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '7 vm = 1.0 log_proj_var =3.94.jpg']
# snr= 1
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '1 vm = 1.0 log_proj_var =4.70.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '10 vm = 0.8594 log_proj_var =0.28.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '7 vm = 0.9437 log_proj_var =2.39.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '4 vm = 1.0 log_proj_var =3.82.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '7 vm = 0.9437 log_proj_var =2.39.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '17 vm = 0.2966 log_proj_var =', '4.92.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '20 vm = 0.1666 log_proj_var =', '6.31.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '10 vm = 0.1666 log_proj_var =', '6.31.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '10 vm = 0.8594 log_proj_var =0.28.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '17 vm = 0.2966 log_proj_var =', '4.92.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '14 vm = 0.5409 log_proj_var =', '3.07.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '10 vm = 0.1666 log_proj_var =', '6.31.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '20 vm = 0.1666 log_proj_var =', '6.31.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '4 vm = 1.0 log_proj_var =3.82.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '14 vm = 0.5409 log_proj_var =', '3.07.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '11 vm = 0.7944 log_proj_var =', '0.54.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '11 vm = 0.7944 log_proj_var =', '0.54.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '1 vm = 1.0 log_proj_var =4.70.jpg']
# snr= 0.8
# file.split() ['n = 8 5Ribsome data true_index at iter', '4 vm = 0.9772 log_proj_var =3.72.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '7 vm = 0.9291 log_proj_var =2.19.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '17 vm = 0.3007 log_proj_var =', '4.79.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '11 vm = 0.7648 log_proj_var =', '0.89.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '14 vm = 0.5240 log_proj_var =', '3.27.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '10 vm = 0.1188 log_proj_var =', '5.59.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '1 vm = 0.9772 log_proj_var =4.65.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '17 vm = 0.3007 log_proj_var =', '4.79.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '4 vm = 0.9772 log_proj_var =3.72.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '10 vm = 0.7944 log_proj_var =', '0.05.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '10 vm = 0.7944 log_proj_var =', '0.05.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '1 vm = 0.9772 log_proj_var =4.65.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '20 vm = 0.1188 log_proj_var =', '5.59.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '11 vm = 0.7648 log_proj_var =', '0.89.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '10 vm = 0.1188 log_proj_var =', '5.59.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '14 vm = 0.5240 log_proj_var =', '3.27.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '7 vm = 0.9291 log_proj_var =2.19.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '20 vm = 0.1188 log_proj_var =', '5.59.jpg']
# snr= 0.6
# file.split() ['n = 8 5Ribsome data true_index at iter', '17 vm = 0.2092 log_proj_var =', '4.97.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '20 vm = 0.0872 log_proj_var =', '5.94.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '10 vm = 0.7214 log_proj_var =', '0.05.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '7 vm = 0.9291 log_proj_var =2.14.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '4 vm = 0.9437 log_proj_var =3.70.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '10 vm = 0.0872 log_proj_var =', '5.94.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '1 vm = 0.9595 log_proj_var =4.65.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '17 vm = 0.2092 log_proj_var =', '4.97.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '10 vm = 0.7214 log_proj_var =', '0.05.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '4 vm = 0.9437 log_proj_var =3.70.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '14 vm = 0.3725 log_proj_var =', '3.21.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '11 vm = 0.6130 log_proj_var =', '0.87.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '14 vm = 0.3725 log_proj_var =', '3.21.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '7 vm = 0.9291 log_proj_var =2.14.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '1 vm = 0.9595 log_proj_var =4.65.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '10 vm = 0.0872 log_proj_var =', '5.94.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '11 vm = 0.6130 log_proj_var =', '0.87.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '20 vm = 0.0872 log_proj_var =', '5.94.jpg']
# snr= 0.4
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '11 vm = 0.5311 log_proj_var =', '0.83.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '10 vm = 0.5730 log_proj_var =', '0.02.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '20 vm = 0.1039 log_proj_var =', '6.41.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '1 vm = 0.8320 log_proj_var =4.61.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '7 vm = 0.6977 log_proj_var =2.07.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '10 vm = 0.1039 log_proj_var =', '6.41.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '17 vm = 0.1638 log_proj_var =', '5.23.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '10 vm = 0.1039 log_proj_var =', '6.41.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '1 vm = 0.8320 log_proj_var =4.61.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '4 vm = 0.7751 log_proj_var =3.64.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '14 vm = 0.3134 log_proj_var =', '3.30.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '4 vm = 0.7751 log_proj_var =3.64.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '20 vm = 0.1039 log_proj_var =', '6.41.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '14 vm = 0.3134 log_proj_var =', '3.30.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '10 vm = 0.5730 log_proj_var =', '0.02.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '7 vm = 0.6977 log_proj_var =2.07.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '17 vm = 0.1638 log_proj_var =', '5.23.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '11 vm = 0.5311 log_proj_var =', '0.83.jpg']
# snr= 0.2
# file.split() ['n = 8 5Ribsome data true_index at iter', '11 vm = 0.3480 log_proj_var =', '0.66.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '7 vm = 0.5552 log_proj_var =2.02.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '4 vm = 0.6435 log_proj_var =3.43.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '14 vm = 0.1701 log_proj_var =', '3.02.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '1 vm = 0.7693 log_proj_var =4.42.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '7 vm = 0.5552 log_proj_var =2.02.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '20 vm = 0.0415 log_proj_var =', '6.44.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '11 vm = 0.3480 log_proj_var =', '0.66.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '10 vm = 0.0415 log_proj_var =', '6.44.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '10 vm = 0.0415 log_proj_var =', '6.44.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '10 vm = 0.3839 log_proj_var =0.10.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '10 vm = 0.3839 log_proj_var =0.10.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '14 vm = 0.1701 log_proj_var =', '3.02.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '1 vm = 0.7693 log_proj_var =4.42.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '17 vm = 0.0810 log_proj_var =', '4.94.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '4 vm = 0.6435 log_proj_var =3.43.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '20 vm = 0.0415 log_proj_var =', '6.44.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '17 vm = 0.0810 log_proj_var =', '4.94.jpg']
# snr= 0.1
# file.split() ['n = 8 5Ribsome data true_index at iter', '1 vm = 0.3901 log_proj_var =4.27.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '20 vm = 0.0368 log_proj_var =', '6.33.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '14 vm = 0.1456 log_proj_var =', '3.05.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '20 vm = 0.0368 log_proj_var =', '6.33.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '17 vm = 0.0717 log_proj_var =', '5.01.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '4 vm = 0.3460 log_proj_var =3.18.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '7 vm = 0.2713 log_proj_var =1.73.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '10 vm = 0.2301 log_proj_var =', '0.05.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '10 vm = 0.0368 log_proj_var =', '6.33.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '10 vm = 0.0368 log_proj_var =', '6.33.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '17 vm = 0.0717 log_proj_var =', '5.01.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '11 vm = 0.2165 log_proj_var =', '0.76.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '4 vm = 0.3460 log_proj_var =3.18.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '10 vm = 0.2301 log_proj_var =', '0.05.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '7 vm = 0.2713 log_proj_var =1.73.jpg']
# file.split() ['n = 8 5Ribsome data k', 'mean at iter', '1 vm = 0.3901 log_proj_var =4.27.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '14 vm = 0.1456 log_proj_var =', '3.05.jpg']
# file.split() ['n = 8 5Ribsome data true_index at iter', '11 vm = 0.2165 log_proj_var =', '0.76.jpg']

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
n = 24
n_list = [2,7, 10, 15,18, 22]
for n in n_list:
    it_list = []
    vm_list = []
    exp_name = f'20220107_n_{n}_MPCA_tsne_iter'
    dir_path = f'/home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo/TSNE_result/{exp_name}'
    from os import listdir
    from os.path import isfile, join
    onlyfiles = [f for f in listdir(dir_path) if isfile(join(dir_path, f))]

    for file in onlyfiles:

        if len(file.split('-')) == 2:
            #print(file.split('-')[1].split())
            it = float(file.split('-')[1].split()[0])
            vm = float(file.split('-')[1].split()[3].split('j')[0][:-1])
            #print(it, vm)
            it_list.append(it)
            vm_list.append(vm)
        it_list = np.array(it_list)
        vm_list = np.array(vm_list)
        sort = np.argsort(it_list)
        it_list = it_list[sort].tolist()
        vm_list = vm_list[sort].tolist()
    
    plt.plot(it_list, vm_list, label = f'n={n}')
plt.title(f'clean 2SDR')
plt.xlabel('iter')
plt.ylabel('v_measure')
plt.legend()
plt.show()
