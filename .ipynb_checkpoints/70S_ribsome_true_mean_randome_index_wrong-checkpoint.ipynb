# %%
import tomosipo as ts
import numpy as np
import pickle
import mrcfile
import numpy as np
from sklearn.manifold import TSNE
from numpy import reshape
import seaborn as sns
import pandas as pd  
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics.cluster import v_measure_score
import os
import matplotlib.pyplot as plt
import astra
from tomosipo.geometry.parallel_vec import *
from scipy.ndimage import zoom

# %matplotlib inline

# %%
data_name = '70s_ribsome_true_mean_random_angles'
os.makedirs(f'./data/{data_name}', exist_ok = True)

with open(f'./data/{data_name}/images.pkl', 'rb') as f:
    new_projection = pickle.load( f)
          
with open(f'./data/{data_name}/angles.pkl', 'rb') as f:
    angles2 = pickle.load( f)
          
with open(f'./data/{data_name}/orientation_matrix.pkl', 'rb') as f:
    Orientation_Vectors = pickle.load(f)
          
with open(f'./data/{data_name}/indexs.pkl', 'rb') as f:
    indexs = pickle.load(f)
print('indexs',indexs[:10])     
with open(f'./data/{data_name}/mean_subtracted_strcut.pkl', 'rb') as f:
    mean_subtracted_strcut = pickle.load(f)
# Out:
# indexs [4 0 3 3 3 1 3 2 4 0]

# %%
print(new_projection.shape)
ProjSize = 34
Proj_geom = astra.create_proj_geom('parallel3d_vec', ProjSize, ProjSize, Orientation_Vectors)
pg = ts.from_astra(Proj_geom)
Proj_geom = astra.create_proj_geom('parallel3d_vec', ProjSize, ProjSize, Orientation_Vectors)
Vol_geom = astra.create_vol_geom(34, 34, 34)
vg = ts.from_astra(Vol_geom)
pg = ts.from_astra(Proj_geom)
A = ts.operator(vg, pg)
"""
print(pg.ray_dir[:5])
print(pg.det_v[:5])
print(pg.det_u[:5])
print(Orientation_Vectors[:5])
print(pg[:5])
"""
# Out:
# (15000, 34, 34)
# '\nprint(pg.ray_dir[:5])\nprint(pg.det_v[:5])\nprint(pg.det_u[:5])\nprint(Orientation_Vectors[:5])\nprint(pg[:5])\n'

# %%
from models import EM_2SDR
n_list = [15, 18]
#n_list.reverse()
b_list = [400,400, 400, 400,400 , 400]#, 100]
#b_list.reverse()
iter_list = [20 for i in range(len(n_list))]

for i in range(len(n_list)):
    n = n_list[i]
    b = b_list[i]
    niter = iter_list[i]
    Images = new_projection[:9200]
    print(Images.shape)
    exp_name = f'20220206_{data_name}_EM_2SDR_n_{n}_new'
    ProjSize, num_image, n_component , num_iter = 34, 9200, n, niter
    batch_size = b
    Vol_geom = astra.create_vol_geom(34, 34, 34)
    #Images = torch.ones(num_image, 48, 48) # fake images for computing purpose

    vg = ts.from_astra(Vol_geom)
    pg = ts.from_astra(Proj_geom)
    op = ts.operator(vg, pg)
    MP3 = EM_2SDR(ProjSize, num_image, n_component, op , Images,Orientation_Vectors, exp_name,mean_subtracted_strcut, indexs, batch_size, niter)
    MP3.fit(start_ratio = 0.1)
# Out:
# (9200, 34, 34)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:76: UserWarning: torch.qr is deprecated in favor of torch.linalg.qr and will be removed in a future PyTorch release.
# The boolean parameter 'some' has been replaced with a string parameter 'mode'.
# Q, R = torch.qr(A, some)
# should be replaced with
# Q, R = torch.linalg.qr(A, 'reduced' if some else 'complete') (Triggered internally at  /opt/conda/conda-bld/pytorch_1634272097173/work/aten/src/ATen/native/BatchLinearAlgebra.cpp:1937.)
#   self.U1.data = torch.qr(self.U1.data)[0]
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.001s...
# [t-SNE] Computed neighbors for 400 samples in 0.011s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 3.468313
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 64.497002
# [t-SNE] KL divergence after 1000 iterations: 0.631162
# self.All_U_kron_shape torch.Size([39304, 3375])
# self.PCs.shape torch.Size([3375, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([4.5526e-09, 4.3824e-09, 4.4198e-09, 4.8258e-09, 4.4583e-09],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# generated
# real
# 677.3173432350159 sec
# 0 batch 1 iteration
# generated
# real
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.000s...
# [t-SNE] Computed neighbors for 400 samples in 0.018s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 2.321654
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 59.872429
# [t-SNE] KL divergence after 1000 iterations: 0.451509
# self.All_U_kron_shape torch.Size([39304, 3375])
# self.PCs.shape torch.Size([3375, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([1.0037e-08, 9.1088e-09, 9.6031e-09, 1.0864e-08, 9.1579e-09],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# 677.2296917438507 sec
# 0 batch 2 iteration
# generated
# real
# 670.7791633605957 sec
# 0 batch 3 iteration
# generated
# real
# 706.987494468689 sec
# 0 batch 4 iteration
# generated
# real
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.000s...
# [t-SNE] Computed neighbors for 400 samples in 0.015s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 3.771078
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 54.806896
# [t-SNE] KL divergence after 1000 iterations: 0.317847
# self.All_U_kron_shape torch.Size([39304, 3375])
# self.PCs.shape torch.Size([3375, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([1.6102e-08, 1.2293e-08, 1.4787e-08, 1.9097e-08, 1.2843e-08],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# 728.4840016365051 sec
# 0 batch 5 iteration
# generated
# real
# ratio / 5
# 659.1918270587921 sec
# 0 batch 6 iteration
# generated
# real
# 632.7866411209106 sec
# 0 batch 7 iteration
# generated
# real
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.001s...
# [t-SNE] Computed neighbors for 400 samples in 0.012s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 4.670840
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 54.138775
# [t-SNE] KL divergence after 1000 iterations: 0.270179
# self.All_U_kron_shape torch.Size([39304, 3375])
# self.PCs.shape torch.Size([3375, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([1.5819e-08, 1.1745e-08, 1.4249e-08, 1.8387e-08, 1.1652e-08],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# 696.9817395210266 sec
# 0 batch 8 iteration
# generated
# real
# 687.9751451015472 sec
# 0 batch 9 iteration
# generated
# real
# 663.0070462226868 sec
# 0 batch 10 iteration
# generated
# real
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.000s...
# [t-SNE] Computed neighbors for 400 samples in 0.006s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 4.881471
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 55.279102
# [t-SNE] KL divergence after 1000 iterations: 0.268697
# self.All_U_kron_shape torch.Size([39304, 3375])
# self.PCs.shape torch.Size([3375, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([1.6549e-08, 1.2319e-08, 1.4828e-08, 1.9281e-08, 1.2056e-08],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# 716.9457545280457 sec
# 0 batch 11 iteration
# generated
# real
# ratio / 5
# 722.6593542098999 sec
# 0 batch 12 iteration
# generated
# real
# 708.7415554523468 sec
# 0 batch 13 iteration
# generated
# real
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.001s...
# [t-SNE] Computed neighbors for 400 samples in 0.008s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 4.772576
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 53.251724
# [t-SNE] KL divergence after 1000 iterations: 0.266191
# self.All_U_kron_shape torch.Size([39304, 3375])
# self.PCs.shape torch.Size([3375, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([1.7363e-08, 1.3109e-08, 1.5572e-08, 2.0293e-08, 1.2845e-08],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# 676.6772739887238 sec
# 0 batch 14 iteration
# generated
# real
# 662.661214351654 sec
# 0 batch 15 iteration
# generated
# real
# 656.9079487323761 sec
# 0 batch 16 iteration
# generated
# real
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.000s...
# [t-SNE] Computed neighbors for 400 samples in 0.006s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 5.106695
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 54.325283
# [t-SNE] KL divergence after 1000 iterations: 0.276162
# self.All_U_kron_shape torch.Size([39304, 3375])
# self.PCs.shape torch.Size([3375, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([1.7918e-08, 1.3628e-08, 1.6119e-08, 2.0945e-08, 1.3308e-08],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# 658.2389345169067 sec
# 0 batch 17 iteration
# generated
# real
# ratio / 5
# 685.4877562522888 sec
# 0 batch 18 iteration
# generated
# real
# 694.1057810783386 sec
# 0 batch 19 iteration
# generated
# real
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.001s...
# [t-SNE] Computed neighbors for 400 samples in 0.008s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 5.413486
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 53.752361
# [t-SNE] KL divergence after 1000 iterations: 0.264790
# self.All_U_kron_shape torch.Size([39304, 3375])
# self.PCs.shape torch.Size([3375, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([1.8507e-08, 1.4205e-08, 1.6674e-08, 2.1659e-08, 1.3831e-08],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# 662.1307396888733 sec
# 0 batch 20 iteration
# generated
# real
# the 0 th iter
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.001s...
# [t-SNE] Computed neighbors for 400 samples in 0.006s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 5.502476
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 53.838440
# [t-SNE] KL divergence after 1000 iterations: 0.253194
# self.All_U_kron_shape torch.Size([39304, 3375])
# self.PCs.shape torch.Size([3375, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([1.8522e-08, 1.4248e-08, 1.6716e-08, 2.1729e-08, 1.3925e-08],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# (9200, 34, 34)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.000s...
# [t-SNE] Computed neighbors for 400 samples in 0.008s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 4.447577
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 62.354038
# [t-SNE] KL divergence after 1000 iterations: 0.522440
# self.All_U_kron_shape torch.Size([39304, 5832])
# self.PCs.shape torch.Size([5832, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([1.5116e-08, 1.4495e-08, 1.4555e-08, 1.4916e-08, 1.2849e-08],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# generated
# real
# 1361.5911560058594 sec
# 0 batch 1 iteration
# generated
# real
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.000s...
# [t-SNE] Computed neighbors for 400 samples in 0.007s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 7.299707
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 59.491638
# [t-SNE] KL divergence after 1000 iterations: 0.486282
# self.All_U_kron_shape torch.Size([39304, 5832])
# self.PCs.shape torch.Size([5832, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([1.5567e-08, 1.3935e-08, 1.4809e-08, 1.6275e-08, 1.3652e-08],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# 1422.8563997745514 sec
# 0 batch 2 iteration
# generated
# real
# 1336.6618628501892 sec
# 0 batch 3 iteration
# generated
# real
# 1359.0991661548615 sec
# 0 batch 4 iteration
# generated
# real
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.001s...
# [t-SNE] Computed neighbors for 400 samples in 0.012s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 7.851683
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 53.928970
# [t-SNE] KL divergence after 1000 iterations: 0.274960
# self.All_U_kron_shape torch.Size([39304, 5832])
# self.PCs.shape torch.Size([5832, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([1.7423e-08, 1.3306e-08, 1.6106e-08, 2.0309e-08, 1.3332e-08],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# 1395.888860464096 sec
# 0 batch 5 iteration
# generated
# real
# ratio / 5
# 1375.0570678710938 sec
# 0 batch 6 iteration
# generated
# real
# 1392.9837577342987 sec
# 0 batch 7 iteration
# generated
# real
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.000s...
# [t-SNE] Computed neighbors for 400 samples in 0.009s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 8.863539
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 51.514515
# [t-SNE] KL divergence after 1000 iterations: 0.297705
# self.All_U_kron_shape torch.Size([39304, 5832])
# self.PCs.shape torch.Size([5832, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([1.6099e-08, 1.2427e-08, 1.5178e-08, 1.7458e-08, 1.1469e-08],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# 1387.7582545280457 sec
# 0 batch 8 iteration
# generated
# real
# 1412.0562436580658 sec
# 0 batch 9 iteration
# generated
# real
# 1358.483196735382 sec
# 0 batch 10 iteration
# generated
# real
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.002s...
# [t-SNE] Computed neighbors for 400 samples in 0.014s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 8.001995
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 53.520576
# [t-SNE] KL divergence after 1000 iterations: 0.292009
# self.All_U_kron_shape torch.Size([39304, 5832])
# self.PCs.shape torch.Size([5832, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([1.7035e-08, 1.3138e-08, 1.6150e-08, 1.8235e-08, 1.2321e-08],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# 1354.0629646778107 sec
# 0 batch 11 iteration
# generated
# real
# ratio / 5
# 1320.4600961208344 sec
# 0 batch 12 iteration
# generated
# real
# 1324.4971277713776 sec
# 0 batch 13 iteration
# generated
# real
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.000s...
# [t-SNE] Computed neighbors for 400 samples in 0.006s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 9.541998
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 52.457027
# [t-SNE] KL divergence after 1000 iterations: 0.246815
# self.All_U_kron_shape torch.Size([39304, 5832])
# self.PCs.shape torch.Size([5832, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([1.6917e-08, 1.3109e-08, 1.6083e-08, 1.8270e-08, 1.2064e-08],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# 1396.239755153656 sec
# 0 batch 14 iteration
# generated
# real
# 1359.779887676239 sec
# 0 batch 15 iteration
# generated
# real
# 1372.8999891281128 sec
# 0 batch 16 iteration
# generated
# real
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.000s...
# [t-SNE] Computed neighbors for 400 samples in 0.010s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 7.574551
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 54.170231
# [t-SNE] KL divergence after 1000 iterations: 0.260248
# self.All_U_kron_shape torch.Size([39304, 5832])
# self.PCs.shape torch.Size([5832, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([1.7426e-08, 1.3601e-08, 1.6577e-08, 1.9059e-08, 1.2857e-08],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# 1347.6539952754974 sec
# 0 batch 17 iteration
# generated
# real
# ratio / 5
# 1318.1335015296936 sec
# 0 batch 18 iteration
# generated
# real

# %%
#pg = ParallelVectorGeometry.from_astra(Proj_geom)

# %%
#vg = ts.volume(shape=(32, 32, 32), size=(1, 1, 1))
#pg = ts.parallel(angles=50, shape=(48, 48), size=(1.5, 1.5))

# %%
"""
Get original mean subtracted structs
"""
with open('./data/3DVA_subtracted_vols34_0205.pkl', 'rb') as  f:
    mean_sbtracted_structs = pickle.load(f)
print(len(mean_sbtracted_structs))
print(type(mean_sbtracted_structs[0]))
for i in range(5):
    mean_sbtracted_structs[i] = mean_sbtracted_structs[i].tolist()
mean_sbtracted_structs = np.array(mean_sbtracted_structs)
print(mean_sbtracted_structs.shape)

# %%
"""
U1 = torch.load('./snap_shot/1229_n_22_MPCA_sigma_j_monitor_0th_55_U1.pt')
U2 = torch.load('./snap_shot/1229_n_22_MPCA_sigma_j_monitor_0th_55_U2.pt')
U3 = torch.load('./snap_shot/1229_n_22_MPCA_sigma_j_monitor_0th_55_U3.pt')
MP3.U1.data = U1.detach()
MP3.U2.data = U2.detach()
MP3.U3.data = U3.detach()
"""

#MP3.fit(start_ratio = 0.1)

# %%
lr = torch.mean(torch.abs(MP3.U1)) * 0.1
print(torch.mean(torch.abs(MP3.U1)))

# %%
#increase batch_size, decrease learning rate
#first load 15 trained component from n = 15 set
"""
U1 = torch.load('./snap_shot/1227_n_18_MPCA_0th_U1.pt')
U2 = torch.load('./snap_shot/1227_n_18_MPCA_0th_U1.pt')
U3 = torch.load('./snap_shot/1227_n_18_MPCA_0th_U1.pt')
MP3.U1.data = U1.detach()
MP3.U2.data = U2.detach()
MP3.U3.data = U3.detach()

"""




#MP3.fit(start_ratio = 0.1)

# %%
MP3.Output_colection()
Coef = np.array(MP3.All_mu)
#Then perform PCA of T-SNE on allMu
print(Coef.shape)

# %%
tsne = TSNE(n_components=2, verbose=1, random_state=123)

"""
x = Coef.reshape(5000, -1)
z = tsne.fit_transform(x) 
"""

# %%
import numpy as np
"""
np.random.seed(0)

indexs = np.random.randint(5, size = 5000)
print(indexs[:10])
df = pd.DataFrame()
df["y"] = indexs
df["comp-1"] = z[:,0]
df["comp-2"] = z[:,1]

sns.scatterplot(x="comp-1", y="comp-2", hue=df.y.tolist(),
                palette=sns.color_palette("hls", 5),
                data=df).set(title="5Ribsome data true label") 

"""

# %%
print(Coef.shape)
Coef = Coef.reshape(9200, -1)
pca = PCA(n_components=5)
pca.fit(Coef)
P_Coef = pca.transform(Coef)
print(P_Coef.shape)

# %%
z = tsne.fit_transform(P_Coef) 
import numpy as np
np.random.seed(0)

# %%
print(z.shape)
#print(len(indexs))

indexs = Index_3DVA[:9200]
print(indexs[:10])
df = pd.DataFrame()
df["y"] = indexs
df["comp-1"] = z[:,0]
df["comp-2"] = z[:,1]

sns.scatterplot(x="comp-1", y="comp-2", hue=df.y.tolist(),
                palette=sns.color_palette("hls", 5),
                data=df).set(title="5Ribsome data true label")

# %%
kmeans = KMeans(n_clusters=5, random_state=0).fit(P_Coef) #k-mean perform on PCA coef
kmeans.labels_

df = pd.DataFrame()
df["y"] = kmeans.labels_
df["comp-1"] = z[:,0]
df["comp-2"] = z[:,1]

sns.scatterplot(x="comp-1", y="comp-2", hue=df.y.tolist(),
                palette=sns.color_palette("hls", 5),
                data=df).set(title="5Ribsome data k-mean")

# %%
print(v_measure_score(indexs, kmeans.labels_))
