# %%
import tomosipo as ts
import numpy as np
import pickle
import mrcfile
import numpy as np
from sklearn.manifold import TSNE
from numpy import reshape
import seaborn as sns
import pandas as pd  
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics.cluster import v_measure_score
import os
import matplotlib.pyplot as plt
import astra
from tomosipo.geometry.parallel_vec import *
from scipy.ndimage import zoom

# %matplotlib inline

# %%
data_name = '70s_ribsome_true_mean_random_angles'
os.makedirs(f'./data/{data_name}', exist_ok = True)

with open(f'./data/{data_name}/images.pkl', 'rb') as f:
    new_projection = pickle.load( f)
          
with open(f'./data/{data_name}/angles.pkl', 'rb') as f:
    angles2 = pickle.load( f)
          
with open(f'./data/{data_name}/orientation_matrix.pkl', 'rb') as f:
    Orientation_Vectors = pickle.load(f)
          
with open(f'./data/{data_name}/indexs.pkl', 'rb') as f:
    indexs = pickle.load(f)
print('indexs',indexs[:10])     
with open(f'./data/{data_name}/mean_subtracted_strcut.pkl', 'rb') as f:
    mean_subtracted_strcut = pickle.load(f)
# Out:
# indexs [4 0 3 3 3 1 3 2 4 0]

# %%
print(new_projection.shape)
ProjSize = 34
Proj_geom = astra.create_proj_geom('parallel3d_vec', ProjSize, ProjSize, Orientation_Vectors)
pg = ts.from_astra(Proj_geom)
Proj_geom = astra.create_proj_geom('parallel3d_vec', ProjSize, ProjSize, Orientation_Vectors)
Vol_geom = astra.create_vol_geom(34, 34, 34)
vg = ts.from_astra(Vol_geom)
pg = ts.from_astra(Proj_geom)
A = ts.operator(vg, pg)
"""
print(pg.ray_dir[:5])
print(pg.det_v[:5])
print(pg.det_u[:5])
print(Orientation_Vectors[:5])
print(pg[:5])
"""
# Out:
# (15000, 34, 34)
# '\nprint(pg.ray_dir[:5])\nprint(pg.det_v[:5])\nprint(pg.det_u[:5])\nprint(Orientation_Vectors[:5])\nprint(pg[:5])\n'

# %%
from models import EM_2SDR
n_list = [5, 15, 18]
#n_list.reverse()
b_list = [400,400, 400, 400,400 , 400]#, 100]
#b_list.reverse()
iter_list = [20 for i in range(len(n_list))]

for i in range(len(n_list)):
    n = n_list[i]
    b = b_list[i]
    niter = iter_list[i]
    Images = new_projection
    print(Images.shape)
    exp_name = f'20220207_{data_name}_EM_2SDR_n_{n}_new'
    ProjSize, num_image, n_component , num_iter = 34, new_projection.shape[0], n, niter
    batch_size = b
    Vol_geom = astra.create_vol_geom(34, 34, 34)
    #Images = torch.ones(num_image, 48, 48) # fake images for computing purpose

    vg = ts.from_astra(Vol_geom)
    pg = ts.from_astra(Proj_geom)
    op = ts.operator(vg, pg)
    MP3 = EM_2SDR(ProjSize, num_image, n_component, op , Images,Orientation_Vectors, exp_name,mean_subtracted_strcut, indexs, batch_size, niter)
    MP3.fit(start_ratio = 0.1)
# Out:
# (15000, 34, 34)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:76: UserWarning: torch.qr is deprecated in favor of torch.linalg.qr and will be removed in a future PyTorch release.
# The boolean parameter 'some' has been replaced with a string parameter 'mode'.
# Q, R = torch.qr(A, some)
# should be replaced with
# Q, R = torch.linalg.qr(A, 'reduced' if some else 'complete') (Triggered internally at  /opt/conda/conda-bld/pytorch_1634272097173/work/aten/src/ATen/native/BatchLinearAlgebra.cpp:1937.)
#   self.U1.data = torch.qr(self.U1.data)[0]
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.000s...
# [t-SNE] Computed neighbors for 400 samples in 0.010s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 0.420534
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 62.166718
# [t-SNE] KL divergence after 1000 iterations: 0.380661
# self.All_U_kron_shape torch.Size([39304, 125])
# self.PCs.shape torch.Size([125, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([4.9815e-09, 4.6626e-09, 4.8659e-09, 5.2934e-09, 4.7069e-09],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# generated
# real
# 25.422722101211548 sec
# 0 batch 1 iteration
# generated
# real
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.000s...
# [t-SNE] Computed neighbors for 400 samples in 0.008s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 0.127462
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 54.111511
# [t-SNE] KL divergence after 1000 iterations: 0.224125
# self.All_U_kron_shape torch.Size([39304, 125])
# self.PCs.shape torch.Size([125, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([1.6529e-08, 1.5101e-08, 1.6019e-08, 1.7945e-08, 1.5382e-08],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# 23.934720277786255 sec
# 0 batch 2 iteration
# generated
# real
# 23.035560369491577 sec
# 0 batch 3 iteration
# generated
# real
# 24.152177572250366 sec
# 0 batch 4 iteration
# generated
# real
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.000s...
# [t-SNE] Computed neighbors for 400 samples in 0.005s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 0.426404
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 51.298679
# [t-SNE] KL divergence after 1000 iterations: 0.156255
# self.All_U_kron_shape torch.Size([39304, 125])
# self.PCs.shape torch.Size([125, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([5.6268e-08, 4.6787e-08, 5.3492e-08, 6.4325e-08, 4.8842e-08],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# 22.52739691734314 sec
# 0 batch 5 iteration
# generated
# real
# ratio / 5
# 22.97709894180298 sec
# 0 batch 6 iteration
# generated
# real
# 21.863661527633667 sec
# 0 batch 7 iteration
# generated
# real
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.000s...
# [t-SNE] Computed neighbors for 400 samples in 0.007s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 0.832143
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 50.210892
# [t-SNE] KL divergence after 1000 iterations: 0.140327
# self.All_U_kron_shape torch.Size([39304, 125])
# self.PCs.shape torch.Size([125, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([5.4793e-08, 4.3576e-08, 5.1736e-08, 6.3692e-08, 4.5909e-08],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# 23.93888521194458 sec
# 0 batch 8 iteration
# generated
# real
# 21.54503846168518 sec
# 0 batch 9 iteration
# generated
# real
# 23.532148122787476 sec
# 0 batch 10 iteration
# generated
# real
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.001s...
# [t-SNE] Computed neighbors for 400 samples in 0.014s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 0.909102
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 50.260040
# [t-SNE] KL divergence after 1000 iterations: 0.125619
# self.All_U_kron_shape torch.Size([39304, 125])
# self.PCs.shape torch.Size([125, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([5.1179e-08, 3.9818e-08, 4.8258e-08, 5.9855e-08, 4.2192e-08],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# 22.94298028945923 sec
# 0 batch 11 iteration
# generated
# real
# ratio / 5
# 21.897446155548096 sec
# 0 batch 12 iteration
# generated
# real
# 22.597872018814087 sec
# 0 batch 13 iteration
# generated
# real
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.000s...
# [t-SNE] Computed neighbors for 400 samples in 0.005s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 0.923521
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 49.756771
# [t-SNE] KL divergence after 1000 iterations: 0.122620
# self.All_U_kron_shape torch.Size([39304, 125])
# self.PCs.shape torch.Size([125, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([4.9414e-08, 3.8031e-08, 4.6579e-08, 5.7899e-08, 4.0403e-08],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# 24.234949827194214 sec
# 0 batch 14 iteration
# generated
# real
# 24.034140825271606 sec
# 0 batch 15 iteration
# generated
# real
# 23.217845916748047 sec
# 0 batch 16 iteration
# generated
# real
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.001s...
# [t-SNE] Computed neighbors for 400 samples in 0.009s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 0.900028
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 49.152802
# [t-SNE] KL divergence after 1000 iterations: 0.126187
# self.All_U_kron_shape torch.Size([39304, 125])
# self.PCs.shape torch.Size([125, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([4.9153e-08, 3.7742e-08, 4.6329e-08, 5.7628e-08, 4.0126e-08],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# 22.274368286132812 sec
# 0 batch 17 iteration
# generated
# real
# ratio / 5
# 22.180166721343994 sec
# 0 batch 18 iteration
# generated
# real
# 20.676753759384155 sec
# 0 batch 19 iteration
# generated
# real
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.000s...
# [t-SNE] Computed neighbors for 400 samples in 0.007s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 0.906996
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 48.671551
# [t-SNE] KL divergence after 1000 iterations: 0.117498
# self.All_U_kron_shape torch.Size([39304, 125])
# self.PCs.shape torch.Size([125, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([4.8975e-08, 3.7578e-08, 4.6161e-08, 5.7433e-08, 3.9965e-08],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# 21.23034405708313 sec
# 0 batch 20 iteration
# generated
# real
# the 0 th iter
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.000s...
# [t-SNE] Computed neighbors for 400 samples in 0.008s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 0.911009
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 49.117561
# [t-SNE] KL divergence after 1000 iterations: 0.124768
# self.All_U_kron_shape torch.Size([39304, 125])
# self.PCs.shape torch.Size([125, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([4.8871e-08, 3.7474e-08, 4.6062e-08, 5.7320e-08, 3.9858e-08],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# (15000, 34, 34)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.001s...
# [t-SNE] Computed neighbors for 400 samples in 0.011s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 3.184017
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 64.684624
# [t-SNE] KL divergence after 1000 iterations: 0.654936
# self.All_U_kron_shape torch.Size([39304, 3375])
# self.PCs.shape torch.Size([3375, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([4.5689e-09, 4.3959e-09, 4.4292e-09, 4.7544e-09, 4.3935e-09],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# generated
# real
# 690.0715782642365 sec
# 0 batch 1 iteration
# generated
# real
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.000s...
# [t-SNE] Computed neighbors for 400 samples in 0.010s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 2.652147
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 59.690964
# [t-SNE] KL divergence after 1000 iterations: 0.477957
# self.All_U_kron_shape torch.Size([39304, 3375])
# self.PCs.shape torch.Size([3375, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([9.6926e-09, 8.8610e-09, 9.1809e-09, 1.0286e-08, 8.6136e-09],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# 673.074871301651 sec
# 0 batch 2 iteration
# generated
# real
# 694.7728335857391 sec
# 0 batch 3 iteration
# generated
# real
# 664.7724456787109 sec
# 0 batch 4 iteration
# generated
# real
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.001s...
# [t-SNE] Computed neighbors for 400 samples in 0.008s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 4.291403
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 53.897324
# [t-SNE] KL divergence after 1000 iterations: 0.288872
# self.All_U_kron_shape torch.Size([39304, 3375])
# self.PCs.shape torch.Size([3375, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([1.7592e-08, 1.3829e-08, 1.5934e-08, 2.1050e-08, 1.4148e-08],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# 637.6343348026276 sec
# 0 batch 5 iteration
# generated
# real
# ratio / 5
# 662.4295880794525 sec
# 0 batch 6 iteration
# generated
# real
# 716.8644554615021 sec
# 0 batch 7 iteration
# generated
# real
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.001s...
# [t-SNE] Computed neighbors for 400 samples in 0.008s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 5.331442
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 53.412529
# [t-SNE] KL divergence after 1000 iterations: 0.265109
# self.All_U_kron_shape torch.Size([39304, 3375])
# self.PCs.shape torch.Size([3375, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([1.6773e-08, 1.2696e-08, 1.4869e-08, 2.0221e-08, 1.2265e-08],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# 682.7914917469025 sec
# 0 batch 8 iteration
# generated
# real
# 668.4369463920593 sec
# 0 batch 9 iteration
# generated
# real
# 639.8250997066498 sec
# 0 batch 10 iteration
# generated
# real
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.001s...
# [t-SNE] Computed neighbors for 400 samples in 0.007s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 5.421950
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 53.475323
# [t-SNE] KL divergence after 1000 iterations: 0.261281
# self.All_U_kron_shape torch.Size([39304, 3375])
# self.PCs.shape torch.Size([3375, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([1.7654e-08, 1.3471e-08, 1.5572e-08, 2.1248e-08, 1.2703e-08],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "
# 658.8599364757538 sec
# 0 batch 11 iteration
# generated
# real
# ratio / 5
# 698.3804135322571 sec
# 0 batch 12 iteration
# generated
# real
# 685.9253251552582 sec
# 0 batch 13 iteration
# generated
# real
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.000s...
# [t-SNE] Computed neighbors for 400 samples in 0.008s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 5.570047
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 54.189842
# [t-SNE] KL divergence after 1000 iterations: 0.254647
# self.All_U_kron_shape torch.Size([39304, 3375])
# self.PCs.shape torch.Size([3375, 5])
# self.ori_var_each tensor([4.7615e-07, 4.6321e-07, 4.6956e-07, 4.8469e-07, 4.5733e-07])
# self.projected_var_each tensor([1.7759e-08, 1.3543e-08, 1.5608e-08, 2.1354e-08, 1.2635e-08],
#        grad_fn=<DivBackward0>)
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/models.py:550: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ms_strucs = torch.permute(torch.tensor(self.ms_strucs), (1, 0))
# /home/users/lewis841214/Desktop/1project/CryoEMCode/GPU_CryoEM/tomosipo_structureed/tomosipo/links/torch.py:64: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   f"The parameter initial_value should be contiguous. "

# %%
#pg = ParallelVectorGeometry.from_astra(Proj_geom)

# %%
#vg = ts.volume(shape=(32, 32, 32), size=(1, 1, 1))
#pg = ts.parallel(angles=50, shape=(48, 48), size=(1.5, 1.5))

# %%
"""
Get original mean subtracted structs
"""
with open('./data/3DVA_subtracted_vols34_0205.pkl', 'rb') as  f:
    mean_sbtracted_structs = pickle.load(f)
print(len(mean_sbtracted_structs))
print(type(mean_sbtracted_structs[0]))
for i in range(5):
    mean_sbtracted_structs[i] = mean_sbtracted_structs[i].tolist()
mean_sbtracted_structs = np.array(mean_sbtracted_structs)
print(mean_sbtracted_structs.shape)

# %%
"""
U1 = torch.load('./snap_shot/1229_n_22_MPCA_sigma_j_monitor_0th_55_U1.pt')
U2 = torch.load('./snap_shot/1229_n_22_MPCA_sigma_j_monitor_0th_55_U2.pt')
U3 = torch.load('./snap_shot/1229_n_22_MPCA_sigma_j_monitor_0th_55_U3.pt')
MP3.U1.data = U1.detach()
MP3.U2.data = U2.detach()
MP3.U3.data = U3.detach()
"""

#MP3.fit(start_ratio = 0.1)

# %%
lr = torch.mean(torch.abs(MP3.U1)) * 0.1
print(torch.mean(torch.abs(MP3.U1)))

# %%
#increase batch_size, decrease learning rate
#first load 15 trained component from n = 15 set
"""
U1 = torch.load('./snap_shot/1227_n_18_MPCA_0th_U1.pt')
U2 = torch.load('./snap_shot/1227_n_18_MPCA_0th_U1.pt')
U3 = torch.load('./snap_shot/1227_n_18_MPCA_0th_U1.pt')
MP3.U1.data = U1.detach()
MP3.U2.data = U2.detach()
MP3.U3.data = U3.detach()

"""




#MP3.fit(start_ratio = 0.1)

# %%
MP3.Output_colection()
Coef = np.array(MP3.All_mu)
#Then perform PCA of T-SNE on allMu
print(Coef.shape)

# %%
tsne = TSNE(n_components=2, verbose=1, random_state=123)

"""
x = Coef.reshape(5000, -1)
z = tsne.fit_transform(x) 
"""

# %%
import numpy as np
"""
np.random.seed(0)

indexs = np.random.randint(5, size = 5000)
print(indexs[:10])
df = pd.DataFrame()
df["y"] = indexs
df["comp-1"] = z[:,0]
df["comp-2"] = z[:,1]

sns.scatterplot(x="comp-1", y="comp-2", hue=df.y.tolist(),
                palette=sns.color_palette("hls", 5),
                data=df).set(title="5Ribsome data true label") 

"""

# %%
print(Coef.shape)
Coef = Coef.reshape(9200, -1)
pca = PCA(n_components=5)
pca.fit(Coef)
P_Coef = pca.transform(Coef)
print(P_Coef.shape)

# %%
z = tsne.fit_transform(P_Coef) 
import numpy as np
np.random.seed(0)

# %%
print(z.shape)
#print(len(indexs))

indexs = Index_3DVA[:9200]
print(indexs[:10])
df = pd.DataFrame()
df["y"] = indexs
df["comp-1"] = z[:,0]
df["comp-2"] = z[:,1]

sns.scatterplot(x="comp-1", y="comp-2", hue=df.y.tolist(),
                palette=sns.color_palette("hls", 5),
                data=df).set(title="5Ribsome data true label")

# %%
kmeans = KMeans(n_clusters=5, random_state=0).fit(P_Coef) #k-mean perform on PCA coef
kmeans.labels_

df = pd.DataFrame()
df["y"] = kmeans.labels_
df["comp-1"] = z[:,0]
df["comp-2"] = z[:,1]

sns.scatterplot(x="comp-1", y="comp-2", hue=df.y.tolist(),
                palette=sns.color_palette("hls", 5),
                data=df).set(title="5Ribsome data k-mean")

# %%
print(v_measure_score(indexs, kmeans.labels_))
